# %% [markdown]
# Mat Plot Lib Tutorial
# =====================
#
# <https://matplotlib.org/contents.html>

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()  # Create a figure containing a single axes.
xs=[1, 2, 3, 4]
ys=[4, 1, 3, 2]
ax.plot(xs, ys)  # Plot some data on the axes.

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4],[5, 4, 3, 2.5])

# %%
plt.plot([-1, 0, 1], [1, 0, 1])

# %%
x = np.linspace(-2, 2, 20)
x
# Out:
# array([-2.        , -1.78947368, -1.57894737, -1.36842105, -1.15789474,
#        -0.94736842, -0.73684211, -0.52631579, -0.31578947, -0.10526316,
#         0.10526316,  0.31578947,  0.52631579,  0.73684211,  0.94736842,
#         1.15789474,  1.36842105,  1.57894737,  1.78947368,  2.        ])

# %%
x**2
# Out:
# array([4.        , 3.20221607, 2.49307479, 1.87257618, 1.34072022,
#        0.89750693, 0.54293629, 0.27700831, 0.09972299, 0.01108033,
#        0.01108033, 0.09972299, 0.27700831, 0.54293629, 0.89750693,
#        1.34072022, 1.87257618, 2.49307479, 3.20221607, 4.        ])

# %%
plt.plot(x, x**2)

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
