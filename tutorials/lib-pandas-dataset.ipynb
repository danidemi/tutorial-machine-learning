# %%
import pandas as pd

# %% [markdown]
# ## Caricamento

# %%
# pclass => passenger class (1st, 2nd, 3rd), and is a proxy for socio-economic class. 
# survived => 1 yes
# age (fractional for babies)
# sibsp => ? (sibgling, spouse?)
# parch => ?
# embarked => port
# boat => id of boat where person was safe
titanic = pd.read_csv("../datasets/titanic.csv")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female      29      0      0   24160  211.3375       B5        S    2
# 1       male  0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female       2      1      2  113781    151.55  C22 C26        S    ?
# 3       male      30      1      2  113781    151.55  C22 C26        S    ?
# 4     female      25      1      2  113781    151.55  C22 C26        S    ?
# ...      ...     ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female    14.5      1      0    2665   14.4542        ?        C    ?
# 1305  female       ?      1      0    2665   14.4542        ?        C    ?
# 1306    male    26.5      0      0    2656     7.225        ?        C    ?
# 1307    male      27      0      0    2670     7.225        ?        C    ?
# 1308    male      29      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
# [1309 rows x 14 columns]

# %%
# Select a series
titanic["age"]
# Out:
# 0           29
# 1       0.9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14.5
# 1305         ?
# 1306      26.5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %%
# how each column is interpreted?
titanic.dtypes
# Out:
# pclass        int64
# survived      int64
# name         object
# sex          object
# age          object
# sibsp         int64
# parch         int64
# ticket       object
# fare         object
# cabin        object
# embarked     object
# boat         object
# body         object
# home.dest    object
# dtype: object

# %%
titanic.describe()
# Out:
#             pclass     survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.498854     0.385027
# std       0.837836     0.486055     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000
# 75%       3.000000     1.000000     1.000000     0.000000
# max       3.000000     1.000000     8.000000     9.000000

# %%
# It is indeed a DataFrame.
# There are 1309.
# Each row has a row label (aka the index) with values ranging from 0 to 1308.
# The table has 14 columns. All columns have a value for each of the rows
# column type => strings = object
# whole numbers
# The approximate amount of RAM used to hold the DataFrame is provided as well.

titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
# Selection based on predicate
firstclass = titanic[ titanic["pclass"]==1 ]
firstclass
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 1         1         1                   Allison, Master. Hudson Trevor
# 2         1         0                     Allison, Miss. Helen Loraine
# 3         1         0             Allison, Mr. Hudson Joshua Creighton
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 318       1         0           Williams-Lambert, Mr. Fletcher Fellows
# 319       1         1                        Wilson, Miss. Helen Alice
# 320       1         1                                Woolner, Mr. Hugh
# 321       1         0                               Wright, Mr. George
# 322       1         1                         Young, Miss. Marie Grice
#
#         sex     age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0    female      29      0      0     24160  211.3375       B5        S    2
# 1      male  0.9167      1      2    113781    151.55  C22 C26        S   11
# 2    female       2      1      2    113781    151.55  C22 C26        S    ?
# 3      male      30      1      2    113781    151.55  C22 C26        S    ?
# 4    female      25      1      2    113781    151.55  C22 C26        S    ?
# ..      ...     ...    ...    ...       ...       ...      ...      ...  ...
# 318    male       ?      0      0    113510        35     C128        S    ?
# 319  female      31      0      0     16966     134.5  E39 E41        C    3
# 320    male       ?      0      0     19947      35.5      C52        S    D
# 321    male      62      0      0    113807     26.55        ?        S    ?
# 322  female      36      0      0  PC 17760  135.6333      C32        C    8
#
#     body                        home.dest
# 0      ?                     St Louis, MO
# 1      ?  Montreal, PQ / Chesterville, ON
# 2      ?  Montreal, PQ / Chesterville, ON
# 3    135  Montreal, PQ / Chesterville, ON
# 4      ?  Montreal, PQ / Chesterville, ON
# ..   ...                              ...
# 318    ?                  London, England
# 319    ?                                ?
# 320    ?                  London, England
# 321    ?                      Halifax, NS
# 322    ?    New York, NY / Washington, DC
#
# [323 rows x 14 columns]

# %%
firstclass.age.unique()
# Out:
# array(['29', '0.9167', '2', '30', '25', '48', '63', '39', '53', '71',
#        '47', '18', '24', '26', '80', '?', '50', '32', '36', '37', '42',
#        '19', '35', '28', '45', '40', '58', '22', '41', '44', '59', '60',
#        '33', '17', '11', '14', '49', '76', '46', '27', '64', '55', '70',
#        '38', '51', '31', '4', '54', '23', '43', '52', '16', '32.5', '21',
#        '15', '65', '28.5', '45.5', '56', '13', '61', '34', '6', '57',
#        '62', '67'], dtype=object)

# %%
# let's select only the the first class with a known age
firstclass = firstclass[ firstclass["age"]!="?" ]

# %%
firstclass.sort_values("age")
# Out:
#      pclass  survived                                               name  \
# 1         1         1                     Allison, Master. Hudson Trevor
# 54        1         1                Carter, Master. William Thornton II
# 249       1         1                        Ryerson, Master. John Borie
# 55        1         1                          Carter, Miss. Lucile Polk
# 193       1         1                  Madill, Miss. Georgette Alexandra
# ..      ...       ...                                                ...
# 81        1         0                       Crosby, Capt. Edward Gifford
# 135       1         0                          Goldschmidt, Mr. George B
# 9         1         0                            Artagaveytia, Mr. Ramon
# 61        1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
#
#         sex     age  sibsp  parch     ticket      fare            cabin  \
# 1      male  0.9167      1      2     113781    151.55          C22 C26
# 54     male      11      1      2     113760       120          B96 B98
# 249    male      13      2      2   PC 17608   262.375  B57 B59 B63 B66
# 55   female      14      1      2     113760       120          B96 B98
# 193  female      15      0      1      24160  211.3375               B5
# ..      ...     ...    ...    ...        ...       ...              ...
# 81     male      70      1      1  WE/P 5735        71              B22
# 135    male      71      0      0   PC 17754   34.6542               A5
# 9      male      71      0      0   PC 17609   49.5042                ?
# 61   female      76      1      0      19877     78.85              C46
# 14     male      80      0      0      27042        30              A23
#
#     embarked boat body                        home.dest
# 1          S   11    ?  Montreal, PQ / Chesterville, ON
# 54         S    4    ?                    Bryn Mawr, PA
# 249        C    4    ?  Haverford, PA / Cooperstown, NY
# 55         S    4    ?                    Bryn Mawr, PA
# 193        S    2    ?                     St Louis, MO
# ..       ...  ...  ...                              ...
# 81         S    ?  269                    Milwaukee, WI
# 135        C    ?    ?                     New York, NY
# 9          C    ?   22              Montevideo, Uruguay
# 61         S    6    ?          Little Onn Hall, Staffs
# 14         S    B    ?                    Hessle, Yorks
#
# [284 rows x 14 columns]

# %%
firstclass.sort_values("age")
# Out:
#      pclass  survived                                               name  \
# 1         1         1                     Allison, Master. Hudson Trevor
# 54        1         1                Carter, Master. William Thornton II
# 249       1         1                        Ryerson, Master. John Borie
# 55        1         1                          Carter, Miss. Lucile Polk
# 193       1         1                  Madill, Miss. Georgette Alexandra
# ..      ...       ...                                                ...
# 81        1         0                       Crosby, Capt. Edward Gifford
# 135       1         0                          Goldschmidt, Mr. George B
# 9         1         0                            Artagaveytia, Mr. Ramon
# 61        1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
#
#         sex     age  sibsp  parch     ticket      fare            cabin  \
# 1      male  0.9167      1      2     113781    151.55          C22 C26
# 54     male      11      1      2     113760       120          B96 B98
# 249    male      13      2      2   PC 17608   262.375  B57 B59 B63 B66
# 55   female      14      1      2     113760       120          B96 B98
# 193  female      15      0      1      24160  211.3375               B5
# ..      ...     ...    ...    ...        ...       ...              ...
# 81     male      70      1      1  WE/P 5735        71              B22
# 135    male      71      0      0   PC 17754   34.6542               A5
# 9      male      71      0      0   PC 17609   49.5042                ?
# 61   female      76      1      0      19877     78.85              C46
# 14     male      80      0      0      27042        30              A23
#
#     embarked boat body                        home.dest
# 1          S   11    ?  Montreal, PQ / Chesterville, ON
# 54         S    4    ?                    Bryn Mawr, PA
# 249        C    4    ?  Haverford, PA / Cooperstown, NY
# 55         S    4    ?                    Bryn Mawr, PA
# 193        S    2    ?                     St Louis, MO
# ..       ...  ...  ...                              ...
# 81         S    ?  269                    Milwaukee, WI
# 135        C    ?    ?                     New York, NY
# 9          C    ?   22              Montevideo, Uruguay
# 61         S    6    ?          Little Onn Hall, Staffs
# 14         S    B    ?                    Hessle, Yorks
#
# [284 rows x 14 columns]
